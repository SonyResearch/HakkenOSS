# %%
from datetime import datetime, timedelta
from pathlib import Path

from hakken_ml_toolkit.file_manager import S3Manager

# %%
remote_path = Path(
    "sai-spaice-ds/ds_project_files/hypotheses_selection_pipeline/batch_3/hypotheses_folder"
)

now = datetime.now() - timedelta(days=50)

now
# Out:
# datetime.datetime(2025, 1, 12, 17, 21, 53, 587348)

# %%
s3_manager = S3Manager()

# %%
df = s3_manager.find()

print(len(df))
df.head()
# Out:
# 23
#                                                 name             creation_date
# 0      aws-quicksetup-patchpolicy-105629644892-pzlbv 2024-01-25 18:01:10+00:00
# 1    gcs-ssm-patching-output-log-bucket-105629644892 2024-01-25 17:59:07+00:00
# 2  gis-patchpolicy-access-log-105629644892-aeb3-p... 2024-01-25 18:00:29+00:00
# 3        infrastructure-development-tfbackend-states 2021-02-06 11:06:37+00:00
# 4         infrastructure-production-tfbackend-states 2021-02-14 08:54:34+00:00

# %%
df = s3_manager.find(folder_path=remote_path)

df

# %%
s3_manager.download_folder(remote_path=remote_path, local_path=Path("./tmp_data"))
