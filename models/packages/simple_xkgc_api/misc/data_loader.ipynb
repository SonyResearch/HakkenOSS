# %%
from simple_xkgc.xkgc_data_loader import XKGCDataLoader
from simple_xkgc.entities.config import XKGCDataConfig

# %%
config = XKGCDataConfig(
data_path="/home/ubuntu/Documents/GitHub/data/hakken_bio/v2/.cache/",
edges_file_path="/home/ubuntu/Documents/GitHub/data/hakken_bio/v2/edges.csv",
gnn_checkpoint_folder="/home/ubuntu/Documents/GitHub/project_spaice_ds/packages/pip/kge/experiments/digital_science/complex/best/kge_best/gnntkge/kge_best",
)

data = XKGCDataLoader.go(config, device="cpu")

# %%
import networkx as nx

nx.diameter(data.graph_u)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[4], line 4
#       1 import networkx as nx
# ----> 4 nx.diameter(data.graph_u)
#
# File ~/Documents/GitHub/project_spaice_ds/packages/pip/simple_xkgc_api/.venv/lib/python3.10/site-packages/networkx/utils/decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:3, in argmap_diameter_1(G, e, usebounds, weight, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# ...
