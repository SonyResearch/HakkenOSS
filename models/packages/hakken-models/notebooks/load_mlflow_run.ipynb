# %%
import json

import mlflow

mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
run_id = "c643763cdb0c4369a2aa60321de2e29c"
run = mlflow.get_run(run_id=run_id)

# %%
params = run.data.params
print(json.dumps(params, indent=4))
# Out:
# {
# ...
